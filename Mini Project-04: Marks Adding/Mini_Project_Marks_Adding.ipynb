# %% [markdown]
# <a href="https://colab.research.google.com/github/Samarjeet09/MiniProjects/blob/main/Mini%20Project-04%3A%20Marks%20Adding/Mini_Project_Marks_Adding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('Mini Project - Marks Adding.csv')
df
# Out:
#        Roll Num  Marks
# 0     102003542      1
# 1     102003640      1
# 2     102003725      1
# 3     102003307      1
# 4     102003458      1
# ...         ...    ...
# 1831  102003755      1
# 1832  102017147      1
# 1833  102017152      1
# 1834  102003451      1
# 1835  102003549      1
#
# [1836 rows x 2 columns]

# %%
d =  {'Roll Num':[],"Marks":[]}
for row in df.index:
  # for each row
  roll = df['Roll Num'][row]
  marks = df['Marks'][row]
  if roll in d['Roll Num']:
    index = d['Roll Num'].index(roll)
    d['Marks'][index] += marks
  else:
    d['Roll Num'].append(roll)
    d['Marks'].append(marks)

# %%
print(d)
# Out:
# {'Roll Num': [102003542, 102003640, 102003725, 102003307, 102003458, 102003643, 102017134, 102003207, 102003315, 102003362, 102003135, 102003650, 102003675, 102003671, 102003374, 102017034, 102003306, 102003141, 102003592, 102003478, 102017030, 102016114, 102003152, 102017101, 102003098, 102003633, 102003132, 102066004, 102003466, 102017188, 102003413, 102016094, 102017190, 102017121, 102003118, 102003681, 102183051, 102017016, 102003649, 102003448, 102003421, 102017152, 102053044, 102003169, 102016049, 102017081, 102053017, 102003299, 102017096, 102003161, 102003109, 102003313, 102003138, 102017078, 102003445, 102003553, 102017186, 102003527, 102003407, 102017100, 102003674, 102183047, 102003160, 102003049, 102003701, 102017159, 102067010, 102003112, 102003522, 102017067, 102003069, 102053019, 102016060, 102003384, 102017169, 102017043, 102017133, 102183052, 102003732, 102003562, 102003235, 102003290, 102003746, 102003694, 102003586, 102003710, 102003439, 102016116, 102003127, 10201
# ...

# %%
newDf = pd.DataFrame(d)
newDf
#
# Out:
#       Roll Num  Marks
# 0    102003542      4
# 1    102003640      5
# 2    102003725      5
# 3    102003307      4
# 4    102003458      5
# ..         ...    ...
# 395  102017150      4
# 396  102003690      1
# 397  102003149      2
# 398  102003089      1
# 399  102180347      1
#
# [400 rows x 2 columns]

# %%
newDf.to_csv("output.csv")
